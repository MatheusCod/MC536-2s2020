# %% [markdown]
# # World Health Organization Data
#
# ## Global Health Observatory
#
# * [Data query API](https://apps.who.int/gho/data/node.resources.api)
# * [GHO OData API ](https://www.who.int/data/gho/info/gho-odata-api)
#
# Exemplos de API: [https://www.who.int/data/gho/info/athena-api-examples](https://www.who.int/data/gho/info/athena-api-examples).
#
# Para se determinar o tipo de informação para acesso veja a [lista de dimensões e códigos](https://apps.who.int/gho/athena/api/GHO). Utilize o código disponível no campo `<Code label="">`. Por exemplo, no campo `<Code Label="WHOSIS_000001">` é possível encontrar o código `WHOSIS_000001` que indica `Life expectancy at birth (years)`.
#
# Depois de estabelecida a informação, podem ser configurados parâmetros, com o sufixo `?` depois da URL. Os parâmetros são separados por `&`.
#
# Os códigos dos países são encontrados em: [https://apps.who.int/gho/athena/api/COUNTRY](https://apps.who.int/gho/athena/api/COUNTRY).

# %% [markdown]
# ## Importando dados em JSON no Python
#
# ![JSON](json.png)

# %%
import io
import requests
import json
url = "https://apps.who.int/gho/athena/api/GHO/WHOSIS_000001?filter=COUNTRY:BRA&format=json"
js = requests.get(url).content
print(js.decode("utf-8"))

# %% [markdown]
# ### Mostrando o Copyright

# %%
import io
import requests
import json
url = "https://apps.who.int/gho/athena/api/GHO/WHOSIS_000001?filter=COUNTRY:BRA&format=json"
data = requests.get(url)
js = data.json()
print(js["copyright"])
# Out:
# (c) World Health Organization

# %% [markdown]
# ## Importando dados em CSV no Python
#
# ![CSV](csv.png)

# %%
import pandas as pd
import io
import requests
url = "https://apps.who.int/gho/athena/api/GHO/WHOSIS_000001?filter=COUNTRY:BRA&format=csv"
data = requests.get(url).content
csv = pd.read_csv(io.StringIO(data.decode("utf-8")))
print(csv)

# %% [markdown]
# # Mostrando o Copyright

# %% [markdown]
# # Importando dados em XML no Python
#
# ![XML](xml.png)

# %%
import io
import requests
import xml.etree.ElementTree as et
url = "https://apps.who.int/gho/athena/api/GHO/WHOSIS_000001?filter=COUNTRY:BRA"
data = requests.get(url).content
x = et.parse(io.StringIO(data.decode("utf-8")))
print(x)
# Out:
# <xml.etree.ElementTree.ElementTree object at 0x7ff5cb490b50>

# %% [markdown]
# # Mostrando o Copyright

# %% [markdown]
# # Tarefa 1
#
# Das fontes de dados disponíveis, tente encontrar fontes com formatos diferentes e importá-las via Python. Busque pelo menos dois formatos.

# %%
import io
import requests
import json
#FONTE: http://metabolomics.helmholtz-muenchen.de/pgwas/
url = "http://metabolomics.helmholtz-muenchen.de/pgwas/download/probeanno.json"
js = requests.get(url)
js = js.json()
aux = 0
for i in js:
    aux += 1
    print(js[i]['target'])
    if (aux == 5):
        break
# Out:
# C4b
# Coagulation Factor XI
# CTACK
# Endostatin
# TIMP-1

# %%
import pandas as pd
import io
import requests
url = "https://zfin.org/action/marker/ZDB-GENE-990415-8/download/orthology"
data = requests.get(url).content
csv = pd.read_csv(io.StringIO(data.decode("utf-8")))
print(csv)
# Out:
#    species symbol  location                   accession            pub_id  \
# 0    Human   PAX2        10     Ensembl:ENSG00000075891  ZDB-PUB-050823-6
# 1    Human   PAX2        10     Ensembl:ENSG00000075891  ZDB-PUB-990507-7
# 2    Human   PAX2        10     Ensembl:ENSG00000075891  ZDB-PUB-050803-7
# 3    Human   PAX2        10     Ensembl:ENSG00000075891  ZDB-PUB-050823-6
# 4    Human   PAX2        10     Ensembl:ENSG00000075891  ZDB-PUB-050209-7
# 5    Human   PAX2        10     Ensembl:ENSG00000075891  ZDB-PUB-990507-7
# 6    Human   PAX2        10                   Gene:5076  ZDB-PUB-050823-6
# 7    Human   PAX2        10                   Gene:5076  ZDB-PUB-990507-7
# 8    Human   PAX2        10                   Gene:5076  ZDB-PUB-050803-7
# 9    Human   PAX2        10                   Gene:5076  ZDB-PUB-050823-6
# 10   Human   PAX2        10                   Gene:5076  ZDB-PUB-050209-7
# 11   Human   PAX2        10                   Gene:5076  ZDB-PUB-990507-7
# 12   Human   PAX2        10                 OMIM:167409  ZDB-PUB-050823-6
# 13   Human   PAX2        10                 OMIM:167409  ZDB-PUB-990507-7
# 14   Human   PAX2        10                 OMIM:167409  ZDB-PUB-050803-7
# 15   Human   PAX2        10                 OMIM:167409  ZDB-PUB-050823-6
# 16   Human   PAX2        10                 OMIM:167409  ZDB-PUB-050209-7
# 17   Human   PAX2        10                 OMIM:167409  ZDB-PUB-990507-7
# 18   Human   PAX2        10                   HGNC:8616  ZDB-PUB-050823-6
# 19   Human   PAX2        10                   HGNC:8616  ZDB-PUB-990507-7
# 20   Human   PAX2        10                   HGNC:8616  ZDB-PUB-050803-7
# 21   Human   PAX2        10                   HGNC:8616  ZDB-PUB-050823-6
# 22   Human   PAX2        10                   HGNC:8616  ZDB-PUB-050209-7
# 23   Human   PAX2        10                   HGNC:8616  ZDB-PUB-990507-7
# 24   Mouse   Pax2        19  Ensembl:ENSMUSG00000004231  ZDB-PUB-990507-7
# 25   Mouse   Pax2        19  Ensembl:ENSMUSG00000004231  ZDB-PUB-980916-4
# 26   Mouse   Pax2        19                   MGI:97486  ZDB-PUB-990507-7
# 27   Mouse   Pax2        19                   MGI:97486  ZDB-PUB-980916-4
# 28   Mouse   Pax2        19                  Gene:18504  ZDB-PUB-990507-7
# 29   Mouse   Pax2        19                  Gene:18504  ZDB-PUB-980916-4
#
#                                evidence
# 0        Amino acid sequence comparison
# 1        Amino acid sequence comparison
# 2   Conserved genome location (synteny)
# 3   Conserved genome location (synteny)
# 4   Conserved genome location (synteny)
# 5   Conserved genome location (synteny)
# 6        Amino acid sequence comparison
# 7        Amino acid sequence comparison
# 8   Conserved genome location (synteny)
# 9   Conserved genome location (synteny)
# 10  Conserved genome location (synteny)
# 11  Conserved genome location (synteny)
# 12       Amino acid sequence comparison
# 13       Amino acid sequence comparison
# 14  Conserved genome location (synteny)
# 15  Conserved genome location (synteny)
# 16  Conserved genome location (synteny)
# 17  Conserved genome location (synteny)
# 18       Amino acid sequence comparison
# 19       Amino acid sequence comparison
# 20  Conserved genome location (synteny)
# 21  Conserved genome location (synteny)
# 22  Conserved genome location (synteny)
# 23  Conserved genome location (synteny)
# 24       Amino acid sequence comparison
# 25       Amino acid sequence comparison
# 26       Amino acid sequence comparison
# 27       Amino acid sequence comparison
# 28       Amino acid sequence comparison
# 29       Amino acid sequence comparison

# %% [markdown]
# # Tarefa 2
#
# ## Engenharia reversa
#
# Monte um diagramas que representem modelos dos dados que você terá acesso e como pretende associá-los. Coloque abaixo uma imagem do diagrama.
